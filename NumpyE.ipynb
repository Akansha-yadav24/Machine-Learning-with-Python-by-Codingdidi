# %%
import numpy as np

# %%
print(np.__version__)

# %%
G=np.zeros(10)
print(G)

# %%
F=np.zeros((10,10))
print(F)

# %%
F=np.pad(F,pad_width=2, mode="constant", constant_values=5)
print(F)

# %%
print("%d bytes " % (G.size*G.itemsize))

# %%
print("%d bytes " % (F.size*F.itemsize))

# %%
np.info(np.zeros)

# %%
G[8]=45
print(G)

# %%
M=np.arange(5,10,2)
print(M)

# %%
M[1]=85
print(M)

# %%
vx=np.nonzero([1,2,3,2510,5,0,2])
print(vx)

# %%
zx=np.eye(3)
print(zx)

# %%
fx=np.random.random((3,3,3))
print(fx)

# %%
fx=np.random.random((10,10))
print(fx)

# %%
fxmin=fx.min()
fxmax = fx.max()
print(fxmin,fxmax)

# %%
fxmin, fxmax = fx.max(),fx.min()

# %%
dc=np.ones((10,10))
print(dc)

# %%
j = fx.mean()

# %%
print(j)

# %%
k=np.random.random(30)
print(k)

# %%
R= np.ones((10,10))
R[1:-1,1:-1]=5
print(R)

# %%
w=np.diag(1+np.arange(4),k=1)
print(w)

# %%
i=np.zeros((8,8),dtype=int)
i[1::2,::2]=1
i[::2,1::2]=1
print(i)

# %%
# (6,7,8)

print(np.unravel_index(99,(6,7,8)))

# %%
color=np.dtype([("r",np.ubyte),
                ("g",np.ubyte),
                ("b",np.ubyte),
                ("a",np.ubyte)])

# %%
h=np.matmul(np.ones((5,3)),np.ones((3,2)))

# %%
print(h)

# %% [markdown]
# 3 to 8

# %%
f= np.arange(11)
f[(3<f) & (f<=8)]*=-1
print(f)
